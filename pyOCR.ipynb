# %%
# test PyOCR
from PIL import Image
import pytesseract
import cv2
import os
  
Dir = './images2'
for image in os.listdir(Dir):
    pytesseract.pytesseract.tesseract_cmd =  r"C:\Program Files\Tesseract-OCR\tesseract.exe"
#     img = Image.open('./images2/'+ image)
    img = cv2.imread('./images2/'+image)
    gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
#     gray = captcha.convert('L')
    
#     print(image,'>>',pytesseract.image_to_string(gray, lang="chi_tra+eng"))
    word = pytesseract.image_to_string(gray, lang="chi_tra+eng")
    if word == " ":
        print(True)
    else:
        print("imgname %s ocr "%image, word)
# Out:
# imgname 089037461.jpg ocr  2H
#
# imgname 089037462.jpg ocr  ayant
#
# imgname 089037463.jpg ocr
#
#
#
#
#
#
#
#
#
#
#
# imgname 089037464.jpg ocr  WORLDWIDE POINTS
#
# imgname 089037465.jpg ocr  WORLDWIDE POINTS
#
# imgname 089037466.jpg ocr  WORLDWIDEPOINTS
#
# imgname 089037467.jpg ocr  WORLDWIDE POIN
#
#
#
# imgname 089037468.jpg ocr
# imgname 089037469.jpg ocr
#
# imgname 089037470.jpg ocr  =)
#
# imgname 089037471.jpg ocr
# imgname 089037472.jpg ocr  ICAST
#
# imgname 089037473.jpg ocr  ICAST
#
# imgname 089037474.jpg ocr  ICAST
#
# imgname 089037475.jpg ocr  ICAST
#
# imgname 089037476.jpg ocr  RRA
#
# imgname 089037477.jpg ocr  野菜 生 活
#
# imgname 089037478.jpg ocr  田園 生 活
#
# imgname 089037479.jpg ocr  If NOK
#
# imgname 089037480.jpg ocr
# imgname 089037481.jpg ocr  AACE
#
#
#
#
#
#
#
# imgname 089037482.jpg ocr
# imgname 089037483.jpg ocr
# imgname 089037484.jpg ocr
#
# imgname 089037485.jpg ocr
#
# imgname 089037486.jpg ocr
# imgname 089037487.jpg ocr  JIN JIN
#
# ...

# %%
from PIL import Image
import pytesseract
import cv2
import os
  

pytesseract.pytesseract.tesseract_cmd =  r"C:\Program Files\Tesseract-OCR\tesseract.exe"
img = cv2.imread('./images2/089037486.jpg')
gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
#     gray = captcha.convert('L')

#     print(image,'>>',pytesseract.image_to_string(gray, lang="chi_tra+eng"))
word = pytesseract.image_to_string(gray, lang="chi_tra+eng")
if word == "":
    print(True)
else:
    print("imgname %s ocr "%image, word)
# Out:
# imgname md6.jpg ocr

# %%
from PIL import Image
import pytesseract
import cv2
import os
  
Dir = './images5'
for image in os.listdir(Dir):
    pytesseract.pytesseract.tesseract_cmd =  r"C:\Program Files\Tesseract-OCR\tesseract.exe"
#     img = Image.open('./images2/'+ image)
    img = cv2.imread('./images5/'+image)
#     gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    
    
    print(image,'>>',pytesseract.image_to_string(img, lang="chi_tra+eng"))
# Out:
# 089037461.jpg >> 2%
#
# 089037462.jpg >> ant
#
# 089037463.jpg >>
#
#
#
#
#
# 089037464.jpg >> WORLDWIDE POINTS
#
# 089037465.jpg >> WORLDWIDE POINTS
#
# 089037466.jpg >> WORLDWIDE POINTS
#
# 089037467.jpg >> WORLDWIDE POINTS
#
# 089037468.jpg >>
# 089037469.jpg >>
# 089037470.jpg >>
# 089037471.jpg >>
# 089037472.jpg >> ICAST
#
# 089037473.jpg >> ICAST
#
# 089037474.jpg >> ICAST
#
# 089037475.jpg >> ICAST
#
# 089037476.jpg >> 蔬菜 生 活
#
# 089037477.jpg >> 野菜 生 活
#
# 089037478.jpg >> 田園 生 活
#
# 089037479.jpg >> I NIK
#
# 089037480.jpg >>
# 089037481.jpg >> AACE
#
#
#
#
#
#
#
# 089037482.jpg >>
# 089037483.jpg >>
# 089037484.jpg >> AALE
#
#
#
#
#
# 089037485.jpg >>
#
# 089037486.jpg >>
# 089037487.jpg >> JIN JIN
#
# 089037488.jpg >>
# 089037489.jpg >> AX
#
# 089037490.jpg >> RE
#
# xo
# afl
# az
#
# ih
#
# 089037491.jpg >> KA REN MONOGATARI
#
# 089037492.jpg >> KA REN
#
# 089037493.jpg >>
# 089037494.jpg >>
# 089037495.jpg >>
# 089037496.jpg >> FEAL AR
#
# 089037497.jpg >>
# ...

# %%
from PIL import Image
import pytesseract
import cv2
  
Dir = './images2'
for image in os.listdir(Dir):
    pytesseract.pytesseract.tesseract_cmd =  r"C:\Program Files\Tesseract-OCR\tesseract.exe"
#     img = Image.open('./images2/'+ image)
    img = cv2.imread('./images2/'+image)
    gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    print(image,'>>',pytesseract.image_to_string(gray, lang="chi_sim+eng"))


# def main():
#     pytesseract.pytesseract.tesseract_cmd = r"C:\Program Files\Tesseract-OCR\tesseract.exe"
#     img = Image.open(r"./database/089037490.jpg")
# #     img.show()
#     print(pytesseract.image_to_string(img, lang="chi_tra+eng"))
# 
# if __name__ == "__main__":
#     main()
# Out:
# 089037461.jpg >> 杯 之 躁
#
# 089037462.jpg >> 断 惑 贼 任 件
#
# 089037463.jpg >>
#
#
#
#
#
#
#
#
#
#
#
# 089037464.jpg >> WORLDWIDE POINTS
#
# 089037465.jpg >> WORLDWIDE POINTS
#
# 089037466.jpg >> WORLDWIDE POINTS
#
# 089037467.jpg >> WORLDWIDE OIN
#
#
#
# 089037468.jpg >>
# 089037469.jpg >>
#
# 089037470.jpg >> =)
#
# 089037471.jpg >>
# 089037472.jpg >> ICAST
#
# 089037473.jpg >> ICAST
#
# 089037474.jpg >> ICAST
#
# 089037475.jpg >> ICAST
#
# 089037476.jpg >> 薛 莱 生 活
#
# 089037477.jpg >> 野 莱 生 活
#
# 089037478.jpg >> 田 圃 生 活
#
# 089037479.jpg >> If NOK
#
# 089037480.jpg >>
# 089037481.jpg >> AACE
#
#
#
#
#
#
#
# 089037482.jpg >>
# 089037483.jpg >>
# 089037484.jpg >>
#
# 089037485.jpg >>
#
# 089037486.jpg >>
# 089037487.jpg >> JIN JIN
#
# 089037488.jpg >>
# 089037489.jpg >> 彩 焰
#
# 089037490.jpg >> 草 闰 能 薛 养 学
# Be
#
# 089037491.jpg >> KA REN MONOGATARI
#
# 089037492.jpg >> KA REN
#
# 089037493.jpg >>
# 089037494.jpg >>
# 089037495.jpg >>
# 089037496.jpg >> 雨 胺 招 取
#
#
#
# ...

# %%
from PIL import Image
import pytesseract
import cv2
  
Dir = './images5'
for image in os.listdir(Dir):
    pytesseract.pytesseract.tesseract_cmd =  r"C:\Program Files\Tesseract-OCR\tesseract.exe"
#     img = Image.open('./images2/'+ image)
    img = cv2.imread('./images5/'+image)
    gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    print(image,'>>',pytesseract.image_to_string(gray, lang="chi_sim+eng"))
# Out:
# 089037461.jpg >> 杯 心 镰
#
# 089037462.jpg >> ant
#
# 089037463.jpg >>
#
#
#
#
#
# 089037464.jpg >> WORLDWIDE POINTS
#
# 089037465.jpg >> WORLDWIDE POINTS
#
# 089037466.jpg >> WORLDWIDE POINTS
#
# 089037467.jpg >> WORLDWIDE POINTS
#
# 089037468.jpg >>
# 089037469.jpg >>
# 089037470.jpg >>
# 089037471.jpg >>
# 089037472.jpg >> ICAST
#
# 089037473.jpg >> ICAST
#
# 089037474.jpg >> ICAST
#
# 089037475.jpg >> ICAST
#
# 089037476.jpg >> 薛 菜 生 活
#
# 089037477.jpg >> 野 萌 生 活
#
# 089037478.jpg >> 田 园 生 活
#
# 089037479.jpg >> 刑 x
#
# 089037480.jpg >>
# 089037481.jpg >> AACE
#
#
#
#
#
# 089037482.jpg >>
# 089037483.jpg >>
# 089037484.jpg >> FIFIL 1
#
#
#
# |
#
# 089037485.jpg >>
#
# 089037486.jpg >>
# 089037487.jpg >> JIN JIN
#
# 089037488.jpg >>
# 089037489.jpg >> 彩 烫
#
# 089037490.jpg >> 詹 学
#
# xo
# afl
# az
#
# ih
#
# 089037491.jpg >> KA REN MONOGATARI
#
# 089037492.jpg >> KA REN
#
# 089037493.jpg >>
# 089037494.jpg >>
# 089037495.jpg >>
# 089037496.jpg >>
#
# 089037497.jpg >>
# ...

# %%
#------- DO NOT EDIT BELOW -------
import sys,os  
from PIL import Image,ImageDraw  
#Code from https://stackoverflow.max-everyday.com/2019/06/python-opencv-denoising/
def getPixel(image,x,y,G,N):
    L = image.getpixel((x,y))
    if L > G:
        L = True
    else:
        L = False
 
    nearDots = 0
    if L == (image.getpixel((x - 1,y - 1)) > G):
        nearDots += 1
    if L == (image.getpixel((x - 1,y)) > G):
        nearDots += 1
    if L == (image.getpixel((x - 1,y + 1)) > G):
        nearDots += 1
    if L == (image.getpixel((x,y - 1)) > G):
        nearDots += 1
    if L == (image.getpixel((x,y + 1)) > G):
        nearDots += 1
    if L == (image.getpixel((x + 1,y - 1)) > G):
        nearDots += 1
    if L == (image.getpixel((x + 1,y)) > G):
        nearDots += 1
    if L == (image.getpixel((x + 1,y + 1)) > G):
        nearDots += 1
 
    if nearDots < N:
        return image.getpixel((x,y-1))
    else:
        return None

# 降噪 Function
def clearNoise(image,G,N,Z):
    draw = ImageDraw.Draw(image)
 
    for i in range(0,Z):
        for x in range(1,image.size[0] - 1):
            for y in range(1,image.size[1] - 1):
                color = getPixel(image,x,y,G,N)
                if color != None:
                    draw.point((x,y),color)

    return image

class CaptchaBroker():

    def decode(self,image_path):
        # open image
        image = Image.open(image_path)

        enhancer = ImageEnhance.Contrast(image)
        image = enhancer.enhance(3.0)
        enhancer = ImageEnhance.Brightness(image)
        image = enhancer.enhance(10.0)

        im2 = image.convert('1')
        im2 = clearNoise(im2,50,4,6)

        w, h = image.size

        if(show_image):
            im2.show()

        #Very important, tesseract-ocr path here
        pytesseract.pytesseract.tesseract_cmd = user_tesseract_cmd
        code = pytesseract.image_to_string(im2)
        #print(code)
        return code

# %%
import os
def get_imlist(path):
    return [os.path.join(path, f) for f in os.listdir(path) if f.endswith('.jpg')]
Dir = './images2'
get_imlist(Dir)

# %%
import re

# %%
line = 'the quick brown fox jumped over a lazy dog'
regex = re.compile('fox')
match = regex.search(line)
match.start()
# Out:
# 16
